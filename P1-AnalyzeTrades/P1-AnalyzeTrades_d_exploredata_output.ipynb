# %% [markdown]
#  # d explore data

# %% [markdown]
# ## Imports

# %%
#for formatting
import jupyter_black

jupyter_black.load(
)

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv("output/c_resulttradewattr.csv")

# %% [markdown]
# ## Basic info

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            Open_Date  \
# 0             0             0           0  2015-06-30 00:00:00
# 1             1            63          19  2015-06-30 00:00:00
# 2             2            62         692  2015-06-30 00:00:00
# 3             3            61          64  2015-06-30 00:00:00
# 4             4            60         761  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-07 14:17:55  FNMAS    1500.0 -2890.12       B        S  ...
# 2  2016-10-24 11:08:39    ENH      50.0  1245.34       B        S  ...
# 3  2016-01-20 15:22:41   VALE    8000.0  6677.80       S        B  ...
# 4  2017-03-10 10:03:51    MKL      10.0  4008.29       B        S  ...
#
#    AAII_Bullish_8-week_Mov Avg  AAII_Bullish_Bull-Bear_Spread  \
# 0                     0.267944                       0.138889
# 1                     0.267944                       0.138889
# 2                     0.267944                       0.138889
# 3                     0.267944                       0.138889
# 4                     0.267944                       0.138889
#
#    AAII_Bullish_Bullish_Average AAII_Bullish_Average_+St. Dev.  \
# 0                      0.376075                       0.476796
# 1                      0.376075                       0.476796
# 2                      0.376075                       0.476796
# 3                      0.376075                       0.476796
# 4                      0.376075                       0.476796
#
#   AAII_Bullish_Average_- St. Dev.  AAII_S&P 500_Weekly_High  \
# 0                        0.275354                   2129.87
# 1                        0.275354                   2129.87
# 2                        0.275354                   2129.87
# 3                        0.275354                   2129.87
# 4                        0.275354                   2129.87
#
#    AAII_S&P 500_Weekly_Low AAII_S&P 500_Weekly_Close  \
# 0                   2082.1                   2108.58
# 1                   2082.1                   2108.58
# 2                   2082.1                   2108.58
# 3                   2082.1                   2108.58
# 4                   2082.1                   2108.58
#
#   AAII_S&P 500_Weekly_Close.1   AAII_Date
# 0                         NaN  2015-06-25
# 1                         NaN  2015-06-25
# 2                         NaN  2015-06-25
# 3                         NaN  2015-06-25
# 4                         NaN  2015-06-25
#
# [5 rows x 69 columns]

# %%
# statistics

df_datawattr.describe(include="all")
# Out:
#         Unnamed: 0.2  Unnamed: 0.1   Unnamed: 0            Open_Date  \
# count    2682.000000   2682.000000  2682.000000                 2682
# unique           NaN           NaN          NaN                 1896
# top              NaN           NaN          NaN  2015-06-30 00:00:00
# freq             NaN           NaN          NaN                   88
# mean     1340.500000   1340.500000  1340.500000                  NaN
# std       774.371035    774.371035   774.371035                  NaN
# min         0.000000      0.000000     0.000000                  NaN
# 25%       670.250000    670.250000   670.250000                  NaN
# 50%      1340.500000   1340.500000  1340.500000                  NaN
# 75%      2010.750000   2010.750000  2010.750000                  NaN
# max      2681.000000   2681.000000  2681.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# count                  2682   2682   2682.000000   2682.000000    2682
# unique                 1681    236           NaN           NaN       2
# top     2023-07-03 10:24:17    BTU           NaN           NaN       B
# freq                      9     66           NaN           NaN    1639
# mean                    NaN    NaN    492.221104    206.788736     NaN
# std                     NaN    NaN    972.280704   3219.953461     NaN
# min                     NaN    NaN      1.000000 -34709.500000     NaN
# 25%                     NaN    NaN     50.000000   -755.500000     NaN
# 50%                     NaN    NaN    150.000000     27.935000     NaN
# 75%                     NaN    NaN    500.000000   1240.840000     NaN
# max                     NaN    NaN  13400.000000  36982.030000     NaN
#
#        CloseAct  ...  AAII_Bullish_8-week_Mov Avg  \
# count      2682  ...                  2682.000000
# unique        2  ...                          NaN
# top           S  ...                          NaN
# freq       1639  ...                          NaN
# mean        NaN  ...                     0.321121
# std         NaN  ...                     0.067512
# min         NaN  ...                     0.213350
# 25%         NaN  ...                     0.267944
# 50%         NaN  ...                     0.309587
# 75%         NaN  ...                     0.368941
# max         NaN  ...                     0.501395
#
#         AAII_Bullish_Bull-Bear_Spread  AAII_Bullish_Bullish_Average  \
# count                     2682.000000                   2682.000000
# unique                            NaN                           NaN
# top                               NaN                           NaN
# freq                              NaN                           NaN
# mean                        -0.019857                      0.376073
# std                          0.162792                      0.000047
# min                         -0.429223                      0.375021
# 25%                         -0.134204                      0.376075
# 50%                         -0.005747                      0.376075
# 75%                          0.107306                      0.376075
# max                          0.365132                      0.376075
#
#        AAII_Bullish_Average_+St. Dev. AAII_Bullish_Average_- St. Dev.  \
# count                     2682.000000                     2682.000000
# unique                            NaN                             NaN
# top                               NaN                             NaN
# freq                              NaN                             NaN
# mean                         0.476796                        0.275350
# std                          0.000007                        0.000090
# min                          0.476619                        0.273423
# 25%                          0.476796                        0.275354
# 50%                          0.476796                        0.275354
# 75%                          0.476796                        0.275354
# max                          0.476882                        0.275354
#
#         AAII_S&P 500_Weekly_High  AAII_S&P 500_Weekly_Low  \
# count                2682.000000              2682.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                 3088.674249              2984.345675
# std                  1022.718822              1009.246444
# min                  1916.990000              1810.100000
# 25%                  2129.870000              2082.100000
# 50%                  2879.220000              2773.360000
# 75%                  3859.750000              3743.520000
# max                  6147.430000              6050.950000
#
#        AAII_S&P 500_Weekly_Close AAII_S&P 500_Weekly_Close.1   AAII_Date
# count                2682.000000                         0.0        2682
# unique                       NaN                         NaN         314
# top                          NaN                         NaN  2016-02-04
# freq                         NaN                         NaN          90
# mean                 3042.073822                         NaN         NaN
# std                  1019.017476                         NaN         NaN
# min                  1851.860000                         NaN         NaN
# 25%                  2108.580000                         NaN         NaN
# 50%                  2810.920000                         NaN         NaN
# 75%                  3801.780000                         NaN         NaN
# max                  6144.150000                         NaN         NaN
#
# [11 rows x 69 columns]

# %%
for c in df_datawattr.columns:
    print(f"trying {c}")
    try:
        temp_df = pd.pivot_table(
            df_datawattr, index=["Open_Year"], values=c, aggfunc="mean"
        )
        temp_df.plot()
    except:
        print(f"{c} didnt work")
# Out:
# trying Unnamed: 0.2
# trying Unnamed: 0.1
# trying Unnamed: 0
# trying Open_Date
# Open_Date didnt work
# trying Close_Date
# Close_Date didnt work
# trying Symbol
# Symbol didnt work
# trying Quantity
# trying Pnl
# trying OpenAct
# OpenAct didnt work
# trying CloseAct
# CloseAct didnt work
# trying Open_Price
# trying Close_Price
# trying Comm_Tot
# trying DATE
# DATE didnt work
# trying ACTION
# ACTION didnt work
# trying QTYCHG
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# trying PRICE
# trying TIME
# TIME didnt work
# trying UNNAMED: 6
# UNNAMED: 6 didnt work
# trying COMMISSION
# trying UNNAMED: 8
# UNNAMED: 8 didnt work
# trying CASH CHG (PNL)
# CASH CHG (PNL) didnt work
# trying COMMENTS
# COMMENTS didnt work
# trying PCTRETURN
# PCTRETURN didnt work
# trying DETAILS
# DETAILS didnt work
# trying STARTDATE
# STARTDATE didnt work
# trying COMPANY NAME (IN ALPHABETICAL ORDER)
# COMPANY NAME (IN ALPHABETICAL ORDER) didnt work
# trying TICKER
# TICKER didnt work
# trying STOP
# STOP didnt work
# trying % TO STOP
# % TO STOP didnt work
# trying CURRENT PRICE
# CURRENT PRICE didnt work
# trying % TO TARGET
# % TO TARGET didnt work
# trying AT PRICE
# AT PRICE didnt work
# trying TARGET
# TARGET didnt work
# trying EPS1
# EPS1 didnt work
# trying EPS2
# EPS2 didnt work
# trying FYEND
# FYEND didnt work
# trying DAYSTOFYEND
# DAYSTOFYEND didnt work
# trying FYEPSNXT
# FYEPSNXT didnt work
# trying GROWTH*0.5TO0.75
# GROWTH*0.5TO0.75 didnt work
# trying ROIC (BW ROA ROE)
# ROIC (BW ROA ROE) didnt work
# trying TGT FWD P/E
# TGT FWD P/E didnt work
# trying YEARS TO NORMALIZATION
# trying LASTUPDATED
# LASTUPDATED didnt work
# trying CATEGORY
# CATEGORY didnt work
# trying COMMENTS.1
# COMMENTS.1 didnt work
# trying FILENAME
# FILENAME didnt work
# trying DayOfWeek0Mon
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# trying Date_YahooFinance
# Date_YahooFinance didnt work
# trying Close_^GSPC
# trying Close_^VIX
# trying Close_^GSPC_200MA
# trying SP500from200MA
# trying Open_Year
# Open_Year didnt work
# trying AAII_0_level_0_Reported_Date
# AAII_0_level_0_Reported_Date didnt work
# trying AAII_1_level_0_Reported_Bullish
# trying AAII_2_level_0_Reported_Neutral
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(
# C:\Users\Stanley\.virtualenvs\P1-AnalyzeTrades-FUwO02Mg\lib\site-packages\pandas\plotting\_matplotlib\core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# trying AAII_3_level_0_Reported_Bearish
# trying AAII_4_level_0_Reported_Total
# trying AAII_Bullish_8-week_Mov Avg
# trying AAII_Bullish_Bull-Bear_Spread
# trying AAII_Bullish_Bullish_Average
# trying AAII_Bullish_Average_+St. Dev.
# trying AAII_Bullish_Average_- St. Dev.
# trying AAII_S&P 500_Weekly_High
# trying AAII_S&P 500_Weekly_Low
# trying AAII_S&P 500_Weekly_Close
# trying AAII_S&P 500_Weekly_Close.1
# AAII_S&P 500_Weekly_Close.1 didnt work
# trying AAII_Date
# AAII_Date didnt work
# C:\Users\Stanley\AppData\Local\Temp\ipykernel_80180\1181192494.py:4: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   temp_df = pd.pivot_table(

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0.2                     int64
# Unnamed: 0.1                     int64
# Unnamed: 0                       int64
# Open_Date                       object
# Close_Date                      object
#                                 ...
# AAII_S&P 500_Weekly_High       float64
# AAII_S&P 500_Weekly_Low        float64
# AAII_S&P 500_Weekly_Close      float64
# AAII_S&P 500_Weekly_Close.1    float64
# AAII_Date                       object
# Length: 69, dtype: object

# %%
df_datawattr.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Open_Date', 'Close_Date',
#        'Symbol', 'Quantity', 'Pnl', 'OpenAct', 'CloseAct', 'Open_Price',
#        'Close_Price', 'Comm_Tot', 'DATE', 'ACTION', 'QTYCHG', 'PRICE', 'TIME',
#        'UNNAMED: 6', 'COMMISSION', 'UNNAMED: 8', 'CASH CHG (PNL)', 'COMMENTS',
#        'PCTRETURN', 'DETAILS', 'STARTDATE',
#        'COMPANY NAME (IN ALPHABETICAL ORDER)', 'TICKER', 'STOP', '% TO STOP',
#        'CURRENT PRICE', '% TO TARGET', 'AT PRICE', 'TARGET', 'EPS1', 'EPS2',
#        'FYEND', 'DAYSTOFYEND', 'FYEPSNXT', 'GROWTH*0.5TO0.75',
#        'ROIC (BW ROA ROE)', 'TGT FWD P/E', 'YEARS TO NORMALIZATION',
#        'LASTUPDATED', 'CATEGORY', 'COMMENTS.1', 'FILENAME', 'DayOfWeek0Mon',
#        'Date_YahooFinance', 'Close_^GSPC', 'Close_^VIX', 'Close_^GSPC_200MA',
#        'SP500from200MA', 'Open_Year', 'AAII_0_level_0_Reported_Date',
#        'AAII_1_level_0_Reported_Bullish', 'AAII_2_level_0_Reported_Neutral',
#        'AAII_3_level_0_Reported_Bearish', 'AAII_4_level_0_Reported_Total',
#        'AAII_Bullish_8-week_Mov Avg', 'AAII_Bullish_Bull-Bear_Spread',
#        'AAII_Bullish_Bullish_Average', 'AAII_Bullish_Average_+St. Dev.',
#        'AAII_Bullish_Average_- St. Dev.', 'AAII_S&P 500_Weekly_High',
#        'AAII_S&P 500_Weekly_Low', 'AAII_S&P 500_Weekly_Close',
#        'AAII_S&P 500_Weekly_Close.1', 'AAII_Date'],
#       dtype='object')

# %%
# placeholder

# %% [markdown]
# ## Try profile

# %%
# TODO do different profiling
# from ydata_profiling import ProfileReport

# %%
# profile = ProfileReport(df_datawattr, title="Report")
#profile #QA large size
