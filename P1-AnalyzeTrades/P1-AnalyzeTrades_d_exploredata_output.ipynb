# %% [markdown]
#  ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            62            52  2015-06-30 00:00:00
# 2           2            61            22  2015-06-30 00:00:00
# 3           3            60           480  2015-06-30 00:00:00
# 4           4            59            64  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-20 15:20:08    FCX    2000.0  3379.40       S        B  ...
# 2  2016-01-08 14:24:59     AR     500.0  -322.00       S        B  ...
# 3  2016-04-07 14:03:00     DW     200.0   520.73       B        S  ...
# 4  2016-01-20 15:22:41   VALE    8000.0  6677.80       S        B  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x            Open_Date  \
# count   2151.000000   2151.000000   2151.000000                 2151
# unique          NaN           NaN           NaN                 1508
# top             NaN           NaN           NaN  2015-06-30 00:00:00
# freq            NaN           NaN           NaN                   86
# mean    1075.000000   1075.000000   1075.000000                  NaN
# std      621.084535    621.084535    621.084535                  NaN
# min        0.000000      0.000000      0.000000                  NaN
# 25%      537.500000    537.500000    537.500000                  NaN
# 50%     1075.000000   1075.000000   1075.000000                  NaN
# 75%     1612.500000   1612.500000   1612.500000                  NaN
# max     2150.000000   2150.000000   2150.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0.1                        int64
# Unnamed: 0_x                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object

# %%
# placeholder
