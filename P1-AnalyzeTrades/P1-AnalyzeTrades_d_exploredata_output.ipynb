# %% [markdown]
#  # d explore data

# %% [markdown]
# ## Imports

# %%
#for formatting
import jupyter_black

jupyter_black.load(
    lab=False,
)

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv("output/c_resulttradewattr.csv")

# %% [markdown]
# ## Basic info

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            Open_Date  \
# 0             0             0           0  2015-06-30 00:00:00
# 1             1            62          14  2015-06-30 00:00:00
# 2             2            61          22  2015-06-30 00:00:00
# 3             3            60         653  2015-06-30 00:00:00
# 4             4            59          64  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-07 14:17:08  FNMAS    2000.0 -3810.12       B        S  ...
# 2  2016-01-08 14:24:59     AR     500.0  -322.00       S        B  ...
# 3  2016-08-11 11:02:04    ENH      75.0   -41.61       B        S  ...
# 4  2016-01-20 15:22:41   VALE    8000.0  6677.80       S        B  ...
#
#    AAII_4_level_0_Reported_Total  AAII_Bullish_8-week_Mov Avg  \
# 0                       1.000001                     0.267944
# 1                       1.000001                     0.267944
# 2                       1.000001                     0.267944
# 3                       1.000001                     0.267944
# 4                       1.000001                     0.267944
#
#    AAII_Bullish_Bull-Bear_Spread AAII_Bullish_Bullish_Average  \
# 0                       0.138889                     0.377495
# 1                       0.138889                     0.377495
# 2                       0.138889                     0.377495
# 3                       0.138889                     0.377495
# 4                       0.138889                     0.377495
#
#   AAII_Bullish_Average_+St. Dev.  AAII_Bullish_Average_- St. Dev.  \
# 0                       0.478443                         0.276547
# 1                       0.478443                         0.276547
# 2                       0.478443                         0.276547
# 3                       0.478443                         0.276547
# 4                       0.478443                         0.276547
#
#    AAII_S&P 500_Weekly_High AAII_S&P 500_Weekly_Low AAII_S&P 500_Weekly_Close  \
# 0                   2129.87                  2082.1                   2108.58
# 1                   2129.87                  2082.1                   2108.58
# 2                   2129.87                  2082.1                   2108.58
# 3                   2129.87                  2082.1                   2108.58
# 4                   2129.87                  2082.1                   2108.58
#
#     AAII_Date
# 0  2015-06-25
# 1  2015-06-25
# 2  2015-06-25
# 3  2015-06-25
# 4  2015-06-25
#
# [5 rows x 71 columns]

# %%
# statistics

df_datawattr.describe(include="all")
# Out:
#         Unnamed: 0.2  Unnamed: 0.1   Unnamed: 0            Open_Date  \
# count    2272.000000   2272.000000  2272.000000                 2272
# unique           NaN           NaN          NaN                 1604
# top              NaN           NaN          NaN  2015-06-30 00:00:00
# freq             NaN           NaN          NaN                   86
# mean     1135.500000   1135.500000  1135.500000                  NaN
# std       656.014227    656.014227   656.014227                  NaN
# min         0.000000      0.000000     0.000000                  NaN
# 25%       567.750000    567.750000   567.750000                  NaN
# 50%      1135.500000   1135.500000  1135.500000                  NaN
# 75%      1703.250000   1703.250000  1703.250000                  NaN
# max      2271.000000   2271.000000  2271.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# count                  2272   2272   2272.000000   2272.000000    2272
# unique                 1459    214           NaN           NaN       2
# top     2021-12-21 12:02:03   AAPL           NaN           NaN       B
# freq                      8     56           NaN           NaN    1445
# mean                    NaN    NaN    521.336708    209.309938     NaN
# std                     NaN    NaN   1033.673507   2413.195083     NaN
# min                     NaN    NaN      1.000000 -26318.050000     NaN
# 25%                     NaN    NaN     50.000000   -677.300000     NaN
# 50%                     NaN    NaN    150.000000      5.270000     NaN
# 75%                     NaN    NaN    500.000000   1028.725000     NaN
# max                     NaN    NaN  13400.000000  36982.030000     NaN
#
#        CloseAct  ...  AAII_4_level_0_Reported_Total  \
# count      2272  ...                    2272.000000
# unique        2  ...                            NaN
# top           S  ...                            NaN
# freq       1445  ...                            NaN
# mean        NaN  ...                       1.000000
# std         NaN  ...                       0.000002
# min         NaN  ...                       0.999900
# 25%         NaN  ...                       1.000000
# 50%         NaN  ...                       1.000000
# 75%         NaN  ...                       1.000000
# max         NaN  ...                       1.000001
#
#         AAII_Bullish_8-week_Mov Avg  AAII_Bullish_Bull-Bear_Spread  \
# count                   2272.000000                    2272.000000
# unique                          NaN                            NaN
# top                             NaN                            NaN
# freq                            NaN                            NaN
# mean                       0.318911                      -0.023541
# std                        0.062357                       0.154508
# min                        0.224482                      -0.429223
# 25%                        0.267944                      -0.129944
# 50%                        0.309515                      -0.004282
# 75%                        0.361794                       0.096894
# max                        0.472053                       0.365132
#
#        AAII_Bullish_Bullish_Average AAII_Bullish_Average_+St. Dev.  \
# count                  2.272000e+03                    2272.000000
# unique                          NaN                            NaN
# top                             NaN                            NaN
# freq                            NaN                            NaN
# mean                   3.774951e-01                       0.478443
# std                    5.552337e-17                       0.000000
# min                    3.774951e-01                       0.478443
# 25%                    3.774951e-01                       0.478443
# 50%                    3.774951e-01                       0.478443
# 75%                    3.774951e-01                       0.478443
# max                    3.774951e-01                       0.478443
#
#         AAII_Bullish_Average_- St. Dev.  AAII_S&P 500_Weekly_High  \
# count                       2272.000000               2272.000000
# unique                              NaN                       NaN
# top                                 NaN                       NaN
# freq                                NaN                       NaN
# mean                           0.276547               2817.952890
# std                            0.000000                790.946365
# min                            0.276547               1916.990000
# 25%                            0.276547               2084.870117
# 50%                            0.276547               2772.390000
# 75%                            0.276547               3279.320000
# max                            0.276547               4818.620000
#
#        AAII_S&P 500_Weekly_Low AAII_S&P 500_Weekly_Close   AAII_Date
# count              2272.000000               2272.000000        2272
# unique                     NaN                       NaN         239
# top                        NaN                       NaN  2016-02-04
# freq                       NaN                       NaN          90
# mean               2716.625440               2771.628125         NaN
# std                 776.193608                785.365427         NaN
# min                1810.100000               1851.860000         NaN
# 25%                2042.560059               2082.419922         NaN
# 50%                2612.860000               2681.050000         NaN
# 75%                3204.130000               3236.920000         NaN
# max                4703.960000               4793.060000         NaN
#
# [11 rows x 71 columns]

# %%
for c in df_datawattr.columns:
    print(f"trying {c}")
    try:
        temp_df = pd.pivot_table(
            df_datawattr, index=["Open_Year"], values=c, aggfunc="mean"
        )
        temp_df.plot()
    except:
        print(f"{c} didnt work")
# Out:
# trying Unnamed: 0.2
# trying Unnamed: 0.1
# trying Unnamed: 0
# trying Open_Date
# Open_Date didnt work
# trying Close_Date
# Close_Date didnt work
# trying Symbol
# Symbol didnt work
# trying Quantity
# trying Pnl
# trying OpenAct
# OpenAct didnt work
# trying CloseAct
# CloseAct didnt work
# trying Open_Price
# trying Close_Price
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# trying Comm_Tot
# trying DATE
# DATE didnt work
# trying ACTION
# ACTION didnt work
# trying QTYCHG
# trying PRICE
# trying TIME
# TIME didnt work
# trying UNNAMED: 6
# UNNAMED: 6 didnt work
# trying COMMISSION
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# trying UNNAMED: 8
# UNNAMED: 8 didnt work
# trying CASH CHG (PNL)
# CASH CHG (PNL) didnt work
# trying COMMENTS
# COMMENTS didnt work
# trying PCTRETURN
# PCTRETURN didnt work
# trying DETAILS
# DETAILS didnt work
# trying STARTDATE
# STARTDATE didnt work
# trying COMPANY NAME (IN ALPHABETICAL ORDER)
# COMPANY NAME (IN ALPHABETICAL ORDER) didnt work
# trying TICKER
# TICKER didnt work
# trying STOP
# STOP didnt work
# trying % TO STOP
# % TO STOP didnt work
# trying CURRENT PRICE
# CURRENT PRICE didnt work
# trying % TO TARGET
# % TO TARGET didnt work
# trying AT PRICE
# AT PRICE didnt work
# trying TARGET
# TARGET didnt work
# trying EPS1
# EPS1 didnt work
# trying EPS2
# EPS2 didnt work
# trying FYEND
# FYEND didnt work
# trying DAYSTOFYEND
# DAYSTOFYEND didnt work
# trying FYEPSNXT
# FYEPSNXT didnt work
# trying GROWTH*0.5TO0.75
# GROWTH*0.5TO0.75 didnt work
# trying ROIC (BW ROA ROE)
# ROIC (BW ROA ROE) didnt work
# trying TGT FWD P/E
# TGT FWD P/E didnt work
# trying YEARS TO NORMALIZATION
# trying LASTUPDATED
# LASTUPDATED didnt work
# trying CATEGORY
# CATEGORY didnt work
# trying COMMENTS.1
# COMMENTS.1 didnt work
# trying FILENAME
# FILENAME didnt work
# trying DayOfWeek0Mon
# trying Date_YahooFinance
# Date_YahooFinance didnt work
# trying Close_^GSPC
# trying Close_^VIX
# trying Close_^GSPC_200MA
# trying SP500from200MA
# trying Open_Year
# Open_Year didnt work
# trying CONS_SENT_Date
# CONS_SENT_Date didnt work
# trying CONS_SENT_Index
# trying Date
# Date didnt work
# trying AAII_0_level_0_Reported_Date
# AAII_0_level_0_Reported_Date didnt work
# trying AAII_1_level_0_Reported_Bullish
# trying AAII_2_level_0_Reported_Neutral
# trying AAII_3_level_0_Reported_Bearish
# trying AAII_4_level_0_Reported_Total
# trying AAII_Bullish_8-week_Mov Avg
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(
# C:\Users\SW\.virtualenvs\P1-AnalyzeTrades-FvHLA50l\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# trying AAII_Bullish_Bull-Bear_Spread
# trying AAII_Bullish_Bullish_Average
# trying AAII_Bullish_Average_+St. Dev.
# trying AAII_Bullish_Average_- St. Dev.
# trying AAII_S&P 500_Weekly_High
# trying AAII_S&P 500_Weekly_Low
# trying AAII_S&P 500_Weekly_Close
# trying AAII_Date
# AAII_Date didnt work
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\1181192494.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0.2                         int64
# Unnamed: 0.1                         int64
# Unnamed: 0                           int64
# Open_Date                           object
# Close_Date                          object
#                                     ...
# AAII_Bullish_Average_- St. Dev.    float64
# AAII_S&P 500_Weekly_High           float64
# AAII_S&P 500_Weekly_Low            float64
# AAII_S&P 500_Weekly_Close          float64
# AAII_Date                           object
# Length: 71, dtype: object

# %%
df_datawattr.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Open_Date', 'Close_Date',
#        'Symbol', 'Quantity', 'Pnl', 'OpenAct', 'CloseAct', 'Open_Price',
#        'Close_Price', 'Comm_Tot', 'DATE', 'ACTION', 'QTYCHG', 'PRICE', 'TIME',
#        'UNNAMED: 6', 'COMMISSION', 'UNNAMED: 8', 'CASH CHG (PNL)', 'COMMENTS',
#        'PCTRETURN', 'DETAILS', 'STARTDATE',
#        'COMPANY NAME (IN ALPHABETICAL ORDER)', 'TICKER', 'STOP', '% TO STOP',
#        'CURRENT PRICE', '% TO TARGET', 'AT PRICE', 'TARGET', 'EPS1', 'EPS2',
#        'FYEND', 'DAYSTOFYEND', 'FYEPSNXT', 'GROWTH*0.5TO0.75',
#        'ROIC (BW ROA ROE)', 'TGT FWD P/E', 'YEARS TO NORMALIZATION',
#        'LASTUPDATED', 'CATEGORY', 'COMMENTS.1', 'FILENAME', 'DayOfWeek0Mon',
#        'Date_YahooFinance', 'Close_^GSPC', 'Close_^VIX', 'Close_^GSPC_200MA',
#        'SP500from200MA', 'Open_Year', 'CONS_SENT_Date', 'CONS_SENT_Index',
#        'Date', 'AAII_0_level_0_Reported_Date',
#        'AAII_1_level_0_Reported_Bullish', 'AAII_2_level_0_Reported_Neutral',
#        'AAII_3_level_0_Reported_Bearish', 'AAII_4_level_0_Reported_Total',
#        'AAII_Bullish_8-week_Mov Avg', 'AAII_Bullish_Bull-Bear_Spread',
#        'AAII_Bullish_Bullish_Average', 'AAII_Bullish_Average_+St. Dev.',
#        'AAII_Bullish_Average_- St. Dev.', 'AAII_S&P 500_Weekly_High',
#        'AAII_S&P 500_Weekly_Low', 'AAII_S&P 500_Weekly_Close', 'AAII_Date'],
#       dtype='object')

# %%
# placeholder

# %% [markdown]
# ## Try profile

# %%
from pandas_profiling import ProfileReport
# Out:
# C:\Users\SW\AppData\Local\Temp\ipykernel_22112\2274191625.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df_datawattr, title="Report")
#profile #QA large size
