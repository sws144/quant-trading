# %% [markdown]
#  ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0            Open_Date  \
# 0             0             0           0  2015-06-30 00:00:00
# 1             1            62          15  2015-06-30 00:00:00
# 2             2            61           5  2015-06-30 00:00:00
# 3             3            60         657  2015-06-30 00:00:00
# 4             4            59          64  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-07 14:17:15   FMCC    3500.0 -2925.12       B        S  ...
# 2  2016-01-07 11:44:15    LYB     200.0 -2773.30       B        S  ...
# 3  2016-08-18 11:16:45    AWH     200.0  -405.17       B        S  ...
# 4  2016-01-20 15:22:41   VALE    8000.0  6677.80       S        B  ...
#
#    AAII_SENT_Total  AAII_SENT_Bullish8WeekMovAvg  AAII_SENT_BullBearSpread  \
# 0              1.0                      0.262389                 -0.124756
# 1              1.0                      0.262389                 -0.124756
# 2              1.0                      0.262389                 -0.124756
# 3              1.0                      0.262389                 -0.124756
# 4              1.0                      0.262389                 -0.124756
#
#   AAII_SENT_BullishAverage AAII_SENT_BullishAverage+StDev  \
# 0                 0.380245                       0.480891
# 1                 0.380245                       0.480891
# 2                 0.380245                       0.480891
# 3                 0.380245                       0.480891
# 4                 0.380245                       0.480891
#
#    AAII_SENT_BullishAverageStDev  AAII_SENT_S&P500WeeklyHigh  \
# 0                       0.279599                     2128.03
# 1                       0.279599                     2128.03
# 2                       0.279599                     2128.03
# 3                       0.279599                     2128.03
# 4                       0.279599                     2128.03
#
#   AAII_SENT_S&P500WeeklyLow AAII_SENT_S&P500WeeklyClose        Date
# 0                   2056.32                     2077.42  2015-07-02
# 1                   2056.32                     2077.42  2015-07-02
# 2                   2056.32                     2077.42  2015-07-02
# 3                   2056.32                     2077.42  2015-07-02
# 4                   2056.32                     2077.42  2015-07-02
#
# [5 rows x 66 columns]

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#         Unnamed: 0.2  Unnamed: 0.1   Unnamed: 0            Open_Date  \
# count    2189.000000   2189.000000  2189.000000                 2189
# unique           NaN           NaN          NaN                 1541
# top              NaN           NaN          NaN  2015-06-30 00:00:00
# freq             NaN           NaN          NaN                   86
# mean     1094.000000   1094.000000  1094.000000                  NaN
# std       632.054191    632.054191   632.054191                  NaN
# min         0.000000      0.000000     0.000000                  NaN
# 25%       547.000000    547.000000   547.000000                  NaN
# 50%      1094.000000   1094.000000  1094.000000                  NaN
# 75%      1641.000000   1641.000000  1641.000000                  NaN
# max      2188.000000   2188.000000  2188.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# count                  2189   2189   2189.000000   2189.000000    2189
# unique                 1407    210           NaN           NaN       2
# top     2021-12-21 12:02:03   AAPL           NaN           NaN       B
# freq                      8     56           NaN           NaN    1400
# mean                    NaN    NaN    536.640018    237.636085     NaN
# std                     NaN    NaN   1049.828720   2403.760013     NaN
# min                     NaN    NaN      1.000000 -26318.050000     NaN
# 25%                     NaN    NaN     50.000000   -648.980000     NaN
# 50%                     NaN    NaN    150.000000      7.330000     NaN
# 75%                     NaN    NaN    550.000000   1035.860000     NaN
# max                     NaN    NaN  13400.000000  36982.030000     NaN
#
#        CloseAct  ...  AAII_SENT_Total  AAII_SENT_Bullish8WeekMovAvg  \
# count      2189  ...      1979.000000                   1979.000000
# unique        2  ...              NaN                           NaN
# top           S  ...              NaN                           NaN
# freq       1400  ...              NaN                           NaN
# mean        NaN  ...         1.000000                      0.315373
# std         NaN  ...         0.000002                      0.060403
# min         NaN  ...         0.999900                      0.236983
# 25%         NaN  ...         1.000000                      0.262586
# 50%         NaN  ...         1.000000                      0.309120
# 75%         NaN  ...         1.000000                      0.357063
# max         NaN  ...         1.000001                      0.472053
#
#         AAII_SENT_BullBearSpread AAII_SENT_BullishAverage  \
# count                1979.000000              1979.000000
# unique                       NaN                      NaN
# top                          NaN                      NaN
# freq                         NaN                      NaN
# mean                   -0.030018                 0.380245
# std                     0.151126                 0.000000
# min                    -0.294589                 0.380245
# 25%                    -0.147583                 0.380245
# 50%                    -0.012345                 0.380245
# 75%                     0.094828                 0.380245
# max                     0.309645                 0.380245
#
#        AAII_SENT_BullishAverage+StDev  AAII_SENT_BullishAverageStDev  \
# count                     1979.000000                    1979.000000
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean                         0.480891                       0.279599
# std                          0.000000                       0.000000
# min                          0.480891                       0.279599
# 25%                          0.480891                       0.279599
# 50%                          0.480891                       0.279599
# 75%                          0.480891                       0.279599
# max                          0.480891                       0.279599
#
#         AAII_SENT_S&P500WeeklyHigh AAII_SENT_S&P500WeeklyLow  \
# count                  1979.000000               1979.000000
# unique                         NaN                       NaN
# top                            NaN                       NaN
# freq                           NaN                       NaN
# mean                   2606.473048               2505.191569
# std                     595.204161                582.451394
# min                    1916.990000               1810.100000
# 25%                    2081.560000               2010.040039
# 50%                    2511.750000               2379.750000
# 75%                    2964.150000               2854.445000
# max                    4151.690000               4120.870000
#
#        AAII_SENT_S&P500WeeklyClose        Date
# count                  1979.000000        1979
# unique                         NaN         190
# top                            NaN  2016-02-11
# freq                           NaN          90
# mean                   2562.899597         NaN
# std                     596.442710         NaN
# min                    1851.860000         NaN
# 25%                    2036.709961         NaN
# 50%                    2473.830000         NaN
# 75%                    2939.510000         NaN
# max                    4124.660000         NaN
#
# [11 rows x 66 columns]

# %%
for c in df_datawattr.columns:
    print(f'trying {c}')  
    try:
        temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
        temp_df.plot()
    except:
        print(f'{c} didnt work')
# Out:
# trying Unnamed: 0.2
# trying Unnamed: 0.1
# trying Unnamed: 0
# trying Open_Date
# Open_Date didnt work
# trying Close_Date
# Close_Date didnt work
# trying Symbol
# Symbol didnt work
# trying Quantity
# trying Pnl
# trying OpenAct
# OpenAct didnt work
# trying CloseAct
# CloseAct didnt work
# trying Open_Price
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# trying Close_Price
# trying Comm_Tot
# trying DATE
# DATE didnt work
# trying ACTION
# ACTION didnt work
# trying QTYCHG
# trying PRICE
# trying TIME
# TIME didnt work
# trying UNNAMED: 6
# UNNAMED: 6 didnt work
# trying COMMISSION
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# trying UNNAMED: 8
# UNNAMED: 8 didnt work
# trying CASH CHG (PNL)
# CASH CHG (PNL) didnt work
# trying COMMENTS
# COMMENTS didnt work
# trying PCTRETURN
# PCTRETURN didnt work
# trying DETAILS
# DETAILS didnt work
# trying STARTDATE
# STARTDATE didnt work
# trying COMPANY NAME (IN ALPHABETICAL ORDER)
# COMPANY NAME (IN ALPHABETICAL ORDER) didnt work
# trying TICKER
# TICKER didnt work
# trying STOP
# STOP didnt work
# trying % TO STOP
# % TO STOP didnt work
# trying CURRENT PRICE
# CURRENT PRICE didnt work
# trying % TO TARGET
# % TO TARGET didnt work
# trying AT PRICE
# AT PRICE didnt work
# trying TARGET
# TARGET didnt work
# trying EPS1
# EPS1 didnt work
# trying EPS2
# EPS2 didnt work
# trying FYEND
# FYEND didnt work
# trying DAYSTOFYEND
# DAYSTOFYEND didnt work
# trying FYEPSNXT
# FYEPSNXT didnt work
# trying GROWTH*0.5TO0.75
# GROWTH*0.5TO0.75 didnt work
# trying ROIC (BW ROA ROE)
# ROIC (BW ROA ROE) didnt work
# trying TGT FWD P/E
# TGT FWD P/E didnt work
# trying YEARS TO NORMALIZATION
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# trying LASTUPDATED
# LASTUPDATED didnt work
# trying CATEGORY
# CATEGORY didnt work
# trying COMMENTS.1
# COMMENTS.1 didnt work
# trying FILENAME
# FILENAME didnt work
# trying DayOfWeek0Mon
# trying Date_YahooFinance
# Date_YahooFinance didnt work
# trying Close_^GSPC
# trying Close_^VIX
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# trying Open_Year
# Open_Year didnt work
# trying AAII_SENT_Date
# AAII_SENT_Date didnt work
# trying AAII_SENT_Bullish
# trying AAII_SENT_Neutral
# trying AAII_SENT_Bearish
# trying AAII_SENT_Total
# trying AAII_SENT_Bullish8WeekMovAvg
# trying AAII_SENT_BullBearSpread
# trying AAII_SENT_BullishAverage
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")
# C:\Users\SW\.virtualenvs\P1-AnalyzeTrades-FvHLA50l\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# trying AAII_SENT_BullishAverage+StDev
# trying AAII_SENT_BullishAverageStDev
# trying AAII_SENT_S&P500WeeklyHigh
# trying AAII_SENT_S&P500WeeklyLow
# trying AAII_SENT_S&P500WeeklyClose
# trying Date
# Date didnt work
# C:\Users\SW\AppData\Local\Temp\ipykernel_2828\2516167558.py:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   temp_df = pd.pivot_table(df_datawattr, index=["Open_Year"], values= c, aggfunc="mean")

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0.2                       int64
# Unnamed: 0.1                       int64
# Unnamed: 0                         int64
# Open_Date                         object
# Close_Date                        object
#                                   ...
# AAII_SENT_BullishAverageStDev    float64
# AAII_SENT_S&P500WeeklyHigh       float64
# AAII_SENT_S&P500WeeklyLow        float64
# AAII_SENT_S&P500WeeklyClose      float64
# Date                              object
# Length: 66, dtype: object

# %%
df_datawattr.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'Open_Date', 'Close_Date',
#        'Symbol', 'Quantity', 'Pnl', 'OpenAct', 'CloseAct', 'Open_Price',
#        'Close_Price', 'Comm_Tot', 'DATE', 'ACTION', 'QTYCHG', 'PRICE', 'TIME',
#        'UNNAMED: 6', 'COMMISSION', 'UNNAMED: 8', 'CASH CHG (PNL)', 'COMMENTS',
#        'PCTRETURN', 'DETAILS', 'STARTDATE',
#        'COMPANY NAME (IN ALPHABETICAL ORDER)', 'TICKER', 'STOP', '% TO STOP',
#        'CURRENT PRICE', '% TO TARGET', 'AT PRICE', 'TARGET', 'EPS1', 'EPS2',
#        'FYEND', 'DAYSTOFYEND', 'FYEPSNXT', 'GROWTH*0.5TO0.75',
#        'ROIC (BW ROA ROE)', 'TGT FWD P/E', 'YEARS TO NORMALIZATION',
#        'LASTUPDATED', 'CATEGORY', 'COMMENTS.1', 'FILENAME', 'DayOfWeek0Mon',
#        'Date_YahooFinance', 'Close_^GSPC', 'Close_^VIX', 'Open_Year',
#        'AAII_SENT_Date', 'AAII_SENT_Bullish', 'AAII_SENT_Neutral',
#        'AAII_SENT_Bearish', 'AAII_SENT_Total', 'AAII_SENT_Bullish8WeekMovAvg',
#        'AAII_SENT_BullBearSpread', 'AAII_SENT_BullishAverage',
#        'AAII_SENT_BullishAverage+StDev', 'AAII_SENT_BullishAverageStDev',
#        'AAII_SENT_S&P500WeeklyHigh', 'AAII_SENT_S&P500WeeklyLow',
#        'AAII_SENT_S&P500WeeklyClose', 'Date'],
#       dtype='object')

# %%
# placeholder
