# %% [markdown]
#   ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            62           565  2015-06-30 00:00:00
# 2           2            61           564  2015-06-30 00:00:00
# 3           3            60           559  2015-06-30 00:00:00
# 4           4            59           507  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-27 12:22:10   AAPL       250 -9393.46       B        S  ...
# 1  2016-02-03 15:19:05   SFBS       300 -1493.13       B        S  ...
# 2  2016-01-27 15:59:33   SFBS       300 -1465.51       B        S  ...
# 3  2016-02-11 11:09:59   SBNY       175 -3277.66       B        S  ...
# 4  2016-01-27 12:24:30    QSR       200  -862.14       B        S  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#          Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# count   1757.000000   1757.000000   1757.000000                 1757
# unique          NaN           NaN           NaN                 1222
# top             NaN           NaN           NaN  2015-06-30 00:00:00
# freq            NaN           NaN           NaN                   85
# mean     878.000000    878.000000    878.000000                  NaN
# std      507.346529    507.346529    507.346529                  NaN
# min        0.000000      0.000000      0.000000                  NaN
# 25%      439.000000    439.000000    439.000000                  NaN
# 50%      878.000000    878.000000    878.000000                  NaN
# 75%     1317.000000   1317.000000   1317.000000                  NaN
# max     1756.000000   1756.000000   1756.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object
