# %% [markdown]
#   ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            63            36  2015-06-30 00:00:00
# 2           2            62            14  2015-06-30 00:00:00
# 3           3            61            23  2015-06-30 00:00:00
# 4           4            60          1914  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-20 15:18:26    SWN    1000.0  -942.70       S        B  ...
# 2  2016-01-07 14:17:08  FNMAS    2000.0 -3810.12       B        S  ...
# 3  2016-01-08 14:25:15   GLNG     500.0  -492.00       S        B  ...
# 4  2021-06-17 12:40:33    MKL       5.0  3024.22       B        S  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#          Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# count   1915.000000   1915.000000   1915.000000                 1915
# unique          NaN           NaN           NaN                 1330
# top             NaN           NaN           NaN  2015-06-30 00:00:00
# freq            NaN           NaN           NaN                   86
# mean     957.000000    957.000000    957.000000                  NaN
# std      552.957201    552.957201    552.957201                  NaN
# min        0.000000      0.000000      0.000000                  NaN
# 25%      478.500000    478.500000    478.500000                  NaN
# 50%      957.000000    957.000000    957.000000                  NaN
# 75%     1435.500000   1435.500000   1435.500000                  NaN
# max     1914.000000   1914.000000   1914.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object
