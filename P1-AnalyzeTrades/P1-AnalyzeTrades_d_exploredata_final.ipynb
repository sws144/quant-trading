# %% [markdown]
#   ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            63            36  2015-06-30 00:00:00
# 2           2            62            48  2015-06-30 00:00:00
# 3           3            60           379  2015-06-30 00:00:00
# 4           4            59           184  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-20 15:18:26    SWN    1000.0  -942.70       S        B  ...
# 2  2016-01-20 15:19:31    FTK    1200.0  6294.30       S        B  ...
# 3  2016-02-17 13:05:00   ORLY      75.0   106.58       B        S  ...
# 4  2016-01-27 14:40:24   LABL     150.0  -117.14       B        S  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#         Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# count   2006.00000    2006.00000    2006.00000                 2006
# unique         NaN           NaN           NaN                 1397
# top            NaN           NaN           NaN  2015-06-30 00:00:00
# freq           NaN           NaN           NaN                   86
# mean    1002.50000    1002.50000    1002.50000                  NaN
# std      579.22664     579.22664     579.22664                  NaN
# min        0.00000       0.00000       0.00000                  NaN
# 25%      501.25000     501.25000     501.25000                  NaN
# 50%     1002.50000    1002.50000    1002.50000                  NaN
# 75%     1503.75000    1503.75000    1503.75000                  NaN
# max     2005.00000    2005.00000    2005.00000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# count                  2006   2006   2006.000000   2006.000000    2006
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object
