# %% [markdown]
#   ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            62            33  2015-06-30 00:00:00
# 2           2            61           247  2015-06-30 00:00:00
# 3           3            60            21  2015-06-30 00:00:00
# 4           4            59           433  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-27 12:22:10   AAPL       250 -9393.46       B        S  ...
# 1  2016-02-03 15:18:36    AIG       300 -1573.10       B        S  ...
# 2  2016-01-07 14:17:15   FMCC      3500 -2925.12       B        S  ...
# 3  2016-01-07 14:12:46    ABX      2000 -4728.00       S        B  ...
# 4  2016-01-21 10:12:00   MPEL      1700  1265.00       S        B  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#         Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# count     1734.000      1734.000      1734.000                 1734
# unique         NaN           NaN           NaN                 1202
# top            NaN           NaN           NaN  2015-06-30 00:00:00
# freq           NaN           NaN           NaN                   85
# mean       866.500       866.500       866.500                  NaN
# std        500.707       500.707       500.707                  NaN
# min          0.000         0.000         0.000                  NaN
# 25%        433.250       433.250       433.250                  NaN
# 50%        866.500       866.500       866.500                  NaN
# 75%       1299.750      1299.750      1299.750                  NaN
# max       1733.000      1733.000      1733.000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# count                  1734   1734   1734.000000   1734.000000    1734
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object
