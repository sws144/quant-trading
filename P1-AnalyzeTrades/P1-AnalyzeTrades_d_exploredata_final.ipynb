# %% [markdown]
#   ## d explore data

# %%
# imports

import pandas as pd

# %%
# read in data

df_datawattr = pd.read_csv('output/c_resulttradewattr.csv')

# %%
# see data
df_datawattr.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# 0           0             0             0  2015-06-30 00:00:00
# 1           1            63            11  2015-06-30 00:00:00
# 2           2            62            10  2015-06-30 00:00:00
# 3           3            61            21  2015-06-30 00:00:00
# 4           4            59            64  2015-06-30 00:00:00
#
#             Close_Date Symbol  Quantity      Pnl OpenAct CloseAct  ...  \
# 0  2016-01-07 11:12:44    AER     600.0 -4851.23       B        S  ...
# 1  2016-01-07 14:16:33  FMCKJ    3500.0 -6285.23       B        S  ...
# 2  2016-01-07 14:12:46    ABX    2000.0 -4728.00       S        B  ...
# 3  2016-01-08 14:24:20     AR     500.0  -327.00       S        B  ...
# 4  2016-01-20 15:22:41   VALE    8000.0  6677.80       S        B  ...
#
#    AAII_Sent_Bearish  AAII_Sent_Total  AAII_Sent_Bullish8WeekMovAvg  \
# 0           0.487055              1.0                       0.24364
# ...

# %%
# statistics

df_datawattr.describe(include='all')
# Out:
#          Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1            Open_Date  \
# count   1958.000000   1958.000000   1958.000000                 1958
# unique          NaN           NaN           NaN                 1361
# top             NaN           NaN           NaN  2015-06-30 00:00:00
# freq            NaN           NaN           NaN                   86
# mean     978.500000    978.500000    978.500000                  NaN
# std      565.370233    565.370233    565.370233                  NaN
# min        0.000000      0.000000      0.000000                  NaN
# 25%      489.250000    489.250000    489.250000                  NaN
# 50%      978.500000    978.500000    978.500000                  NaN
# 75%     1467.750000   1467.750000   1467.750000                  NaN
# max     1957.000000   1957.000000   1957.000000                  NaN
#
#                  Close_Date Symbol      Quantity           Pnl OpenAct  \
# ...

# %%
# columns

df_datawattr.dtypes
# Out:
# Unnamed: 0                          int64
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# Open_Date                          object
# Close_Date                         object
#                                    ...
# AAII_Sent_BullishAverage+StDev    float64
# AAII_Sent_BullishAverageStDev     float64
# AAII_Sent_S&P500WeeklyHigh        float64
# AAII_Sent_S&P500WeeklyLow         float64
# AAII_Sent_S&P500WeeklyClose       float64
# Length: 64, dtype: object

# %%
# placeholder
